# %%
from semantic_kernel import Kernel
from semantic_kernel.connectors.ai.open_ai import AzureChatCompletion
from semantic_kernel.connectors.ai.open_ai import AzureChatPromptExecutionSettings
import os
from langsmith import traceable
import json
import asyncio
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
AZURE_OPENAI_API_KEY=os.environ["AZURE_OPENAI_API_KEY"]
AZURE_OPENAI_ENDPOINT=os.environ["AZURE_OPENAI_ENDPOINT"]
AZURE_OPENAI_API_VERSION=os.environ["AZURE_OPENAI_API_VERSION"]

# %%
kernel = Kernel()

service = AzureChatCompletion(
    deployment_name="gpt-4o-mini",
    endpoint=AZURE_OPENAI_ENDPOINT,
    api_key=AZURE_OPENAI_API_KEY,
    api_version=AZURE_OPENAI_API_VERSION
)

kernel.add_service(service)

# %%
research_prompt = """
You are a research agent.

Provide factual explanation and key points for:
{{$input}}
"""

request_settings_researcher = AzureChatPromptExecutionSettings(temperature=0.1,max_tokens=1000)
research_fn = kernel.add_function(plugin_name="team", function_name="researcher", 
                                  prompt=research_prompt, 
                                  prompt_execution_settings=request_settings_researcher)

@traceable(name="Research Agent")
async def run_research(q):
    return await kernel.invoke(research_fn, input=q)

# %%
analysis_prompt = """
You are an analyst agent.

Critically evaluate the topic:
{{$input}}

Highlight strengths, weaknesses, risks.
"""
request_settings_analyzer = AzureChatPromptExecutionSettings(temperature=0.1,max_tokens=1000)
analysis_fn = kernel.add_function(plugin_name="team",
                                  function_name="analyst",
                                  prompt=analysis_prompt,
                                  prompt_execution_settings=request_settings_analyzer)

@traceable(name="Analyst Agent")
async def run_analysis(q):
    return await kernel.invoke(analysis_fn, input=q)

# %%
synth_prompt = """
You are a synthesis agent.

Combine research and analysis into a balanced final answer.

Research:
{{$research}}

Analysis:
{{$analysis}}
"""
request_settings_synthesizer = AzureChatPromptExecutionSettings(temperature=0.1,max_tokens=1000)
synth_fn = kernel.add_function(plugin_name="team", 
                               function_name="synthesizer", 
                               prompt=synth_prompt,
                               prompt_execution_settings=request_settings_synthesizer)


@traceable(name="Synthesis Agent")
async def run_synth(research, analysis):
    return await kernel.invoke(
        synth_fn,
        research=research,
        analysis=analysis
    )

# %%
@traceable(name="Collaboration Stage")
async def collaboration_stage(q):

    research_task = asyncio.create_task(run_research(q))
    analysis_task = asyncio.create_task(run_analysis(q))

    research_res, analysis_res = await asyncio.gather(
        research_task, analysis_task
    )

    return str(research_res), str(analysis_res)

# %%
@traceable(name="Multi-Agent Collaboration")
async def collaborative_agent(user_question):

    research, analysis = await collaboration_stage(user_question)

    final_answer = await run_synth(research, analysis)

    return final_answer

# %%
answer = await collaborative_agent(
    "How does hybrid retrieval improve RAG systems?"
)

# %%
print(answer)
# Out:
# Hybrid retrieval systems represent a significant advancement in the field of Retrieval-Augmented Generation (RAG) by integrating various retrieval methods to optimize both information retrieval and generation tasks. This synthesis of research and analysis highlights the strengths, weaknesses, and risks associated with hybrid retrieval, providing a comprehensive understanding of its impact on RAG systems.
#
# ### Strengths of Hybrid Retrieval in RAG Systems
#
# 1. **Enhanced Relevance and Precision**:
#    - By combining traditional keyword-based retrieval methods (like TF-IDF or BM25) with neural retrieval techniques (such as dense vector embeddings), hybrid systems can leverage the strengths of both approaches. Traditional methods ensure precision through exact keyword matches, while neural methods enhance semantic understanding, leading to more contextually relevant results.
#
# 2. **Improved Coverage and Recall**:
#    - Hybrid retrieval systems can access a broader range of data sources, including structured databases and unstructured text. This diversity allows for improved recall, capturing a wider array of potentially relevant documents, which is particularly beneficial in domains with varied terminology or synonyms.
#
# 3. **Robustness to Query Variability**:
#    - The adaptability of hybrid systems enables them to handle different types of queries effectively, whether they are factual or require nuanced understanding. This flexibility enhances user satisfaction by providing more accurate and contextually appropriate responses.
#
# 4. **Reduction of Hallucinations**:
#    - By retrieving factual information from reliable sources, hybrid retrieval can mitigate the risk of "hallucinations" in generative models, where incorrect or fabricated information is produced. This leads to higher-quality outputs that align more closely with user queries.
#
# ### Weaknesses of Hybrid Retrieval
#
# 1. **Complexity in Implementation**:
#    - The integration of multiple retrieval methods can complicate system design, requiring careful orchestration to ensure that different components work together effectively. This complexity can lead to longer development times and increased resource allocation.
#
# 2. **Latency and Resource Intensity**:
#    - The combination of various retrieval techniques may introduce latency in response times, potentially impacting user experience, especially in real-time applications. Additionally, hybrid systems may demand more computational resources, leading to higher operational costs.
#
# 3. **Maintenance Challenges**:
#    - Maintaining a hybrid retrieval system can be more demanding than a single-method system, necessitating ongoing adjustments and updates to multiple components to ensure optimal performance.
#
# ### Risks Associated with Hybrid Retrieval
#
# 1. **Bias and Overfitting**:
#    - There is a risk that hybrid systems may become biased if they overly rely on one retrieval method, potentially leading to suboptimal generation outcomes. For instance, an overemphasis on keyword-based retrieval could overlook nuanced semantic meanings.
#
# 2. **Data Privacy and Security Concerns**:
#    - The integration of data from multiple sources raises ethical and legal issues regarding data privacy. Hybrid systems may inadvertently expose sensitive information, necessitating careful compliance with data protection regulations.
#
# 3. **Quality Control Issues**:
#    - The quality of retrieved documents can vary significantly, especially when drawing from diverse sources. Poor-quality or irrelevant documents can undermine the effectiveness of the generative model, leading to inconsistent output quality.
#
# 4. **User Trust and Transparency**:
#    - Users may struggle to trust the outputs of hybrid systems if the retrieval process lacks transparency. This skepticism can diminish confidence in the reliability of the information provided.
#
# ### Conclusion
#
# In summary, hybrid retrieval systems significantly enhance RAG systems by improving relevance, coverage, and robustness while also reducing the likelihood of hallucinations. However, the complexity of implementation, potential latency, and resource demands present notable challenges. Additionally, risks related to bias, data privacy, and quality control must be carefully managed. A balanced approach is essential to maximize the benefits of hybrid retrieval while mitigating its associated risks, ultimately leading to more effective and trustworthy RAG systems.
